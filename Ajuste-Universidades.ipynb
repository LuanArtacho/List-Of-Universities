# %% [markdown]
# ### Codigo para ajustar a celula do excel

# %%
import pandas as pd

# %% [markdown]
# # List with some Universities of Europe

# %%
df = pd.read_excel("Universidades.xlsx", sheet_name="europe")

df["Universidade"] = df["University of Oxford - https://www.ox.ac.uk/"].apply(lambda x: x.split("-")[0])
df["link"] = df["University of Oxford - https://www.ox.ac.uk/"].apply(lambda x: x.split("-")[1])
del df["University of Oxford - https://www.ox.ac.uk/"]
df
# Save the data
df.to_excel("List of many Universities Europe.xlsx", sheet_name="Europe")
df
# Desafio para quem esta vendo, e eu fiquei com sono.. to fznd as 6h da manha das minhas ferias...
# Inserir Universidade de Oxford : https://www.ox.ac.uk/
# Out:
#                                          Universidade  \
# 0                            University of Cambridge
# 1                            Imperial College London
# 2                    University College London (UCL)
# 3                            University of Edinburgh
# 4                           University of Manchester
# 5                               University of Zurich
# 6                            University of Amsterdam
# 7                           University of Copenhagen
# 8   Swiss Federal Institute of Technology Zurich (...
# 9                                University of Paris
# 10                               Sorbonne University
# 11                              University of Vienna
# 12                            University of Helsinki
# 13  Ludwig Maximilian University of Munich (LMU Mu...
# 14                           University of Barcelona
# 15                                         KU Leuven
# 16                                 Leiden University
# ...

# %% [markdown]
# # List with some Universities of USA

# %%
df = pd.read_excel("Universidades.xlsx", sheet_name="usa")
# Save the data
df.to_excel("List of many Universities USA.xlsx", sheet_name="USA")
df
# Out:
#     Rank                             University                        Website
# 0      1                     Harvard University       https://www.harvard.edu/
# 1      2  Massachusetts Institute of Technology           https://www.mit.edu/
# 2      3                    Stanford University      https://www.stanford.edu/
# 3      4     California Institute of Technology       https://www.caltech.edu/
# 4      5                   Princeton University     https://www.princeton.edu/
# 5      6                    Columbia University      https://www.columbia.edu/
# 6      7                  University of Chicago      https://www.uchicago.edu/
# 7      8                        Yale University          https://www.yale.edu/
# 8      9             University of Pennsylvania         https://www.upenn.edu/
# 9     10               Johns Hopkins University           https://www.jhu.edu/
# 10    11     University of California, Berkeley      https://www.berkeley.edu/
# ...

# %% [markdown]
# # List with some Universities of Asia

# %%
df = pd.read_excel("Universidades.xlsx", sheet_name="asia")

df["Link"] = df["Universities"].apply(lambda x: x.split("-")[1])
df["Universities"] = df["Universities"].apply(lambda x: x.split("-")[0])

# Save the data
df.to_excel("List of many Universities Asia.xlsx", sheet_name="Asia")
df
# Out:
#                                          Universities  \
# 0             National University of Singapore (NUS)
# 1                                Tsinghua University
# 2             Nanyang Technological University (NTU)
# 3                                University of Tokyo
# 4                                  Peking University
# 5   Hong Kong University of Science and Technology...
# 6                                   Kyoto University
# 7                    Seoul National University (SNU)
# 8                                   Fudan University
# 9                      Shanghai Jiao Tong University
# 10  Korea Advanced Institute of Science and Techno...
# 11                               Zhejiang University
# 12                  National Taiwan University (NTU)
# 13                     University of Hong Kong (HKU)
# 14  University of Science and Technology of China ...
# 15                     Tokyo Institute of Technology
# 16  Pohang University of Science and Technology (P...
# ...

# %%
# # Import the data
# df = pd.read_excel("Universidades.xlsx", sheet_name="c links")

# # Split the data into two columns
# df["Link"] = df["Universidade"].apply(lambda x: x.split("//")[-1])
# df
# df["Universidade"] = df["Universidade"].apply(lambda x: x.split(":")[0])
# del df["link"]
# df["Universidade"] = df["Universidade"].apply(lambda x: x.split(".")[1])
# df
# # Save the data
# df.to_excel("List of many Universities.xlsx", sheet_name="Att")
